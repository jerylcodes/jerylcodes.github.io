# %% [markdown]
# <img src="https://i.imgur.com/iYGFYFv.png" style="float: left; margin: 15px; height: 80px">
#
# ### Web Scraping and Analysis
# ---
# For this project, we will explore web scraping to obtain data from websites. More specifically, we will be looking at job search websites to obtain job listings together with job descriptions and salary information. We will next use the information scraped to predict salary or classify jobs according to its description. Classifying jobs according to job description involves analysing textual information. We can make use of scikit learn's natural language processing packages to help us in our analysis.
#
# Packages used:
# 1. BeautifulSoup
# 2. pandas
# 3. urllib3
# 4. re
# 5. pickle
# 6. matplotlib
# 7. seaborn
# 8. scikit-learn
# 9. imblearn

# %% [markdown]
# <img src="https://i.imgur.com/wLPdKgZ.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 1.1 Getting the links from the job site for scraping using BeautifulSoup and urllib3

# %%
url = 'https://jobscentral.com.sg/jobsearch?q=data%20science&pg='
urllist = []
for i in range(1,15):
    a = url + str(i)
    urllist.append(a)

# %%
links = []

for link in urllist:
    http = urllib3.PoolManager()
    response = http.request('GET', link)
    soup = BeautifulSoup(response.data, "html.parser")
    
    a = soup.find_all('a',attrs={"class":"job-title"}, href=True)

    for val in a:
        linkstr = 'https://jobscentral.com.sg' + val['href']
        if linkstr not in links:
            links.append(linkstr)
# Out:
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda2\envs\py36\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# ### 1.2 Append results into pandas dataframe

# %%
df
# Out:
#                                                  Title  \
# 0                         Senior/Data Science Engineer
# 1                                    BIG DATA ENGINEER
# 2                         TPCE Data Analytics Engineer
# 3        Project Manager – Analytics & Data Management
# 4    VP/AVP, Data Engineer - Corporate Treasury, Gr...
# 5    VP/AVP, Audit Digitalization Lead - Data Analy...
# 6    SERVICE DELIVERY SPECIALIST (SHIFT WORK) (DATA...
# 7    CRITICAL INFRA SOLUTIONING & PROVISIONING (CIS...
# 8    SERVICE DELIVERY & NOC TEAM LEAD (DATA CENTRE)...
# 9                      System Analyst (Data Profiling)
# 10   Looking for a Big Data Developer for a Permane...
# 11                                Data Center Operator
# 12               Senior/ Data Scientist (KDM/ILS/OBH1)
# 13               Senior/ Data Scientist (KDM/ILS/OBH1)
# 14               Senior/ Data Scientist (KDM/ILS/OBH1)
# 15                       Data Analyst (EAST/IMMEDIATE)
# 16                                        Data Analyst
# 17   Senior / Software Developers  (AI, Big Data, E...
# 18                Data Integration Development Support
# 19           Assistant / Deputy Manager, Data Analysis
# 20                    Facilities Manager (Data Center)
# 21          Job Opportunity for Network Data Architect
# 22                                      Data Scientist
# 23                                Fab10 Data Scientist
# 24                        MCT Big Data Senior Engineer
# 25                        MCT Big Data Senior Engineer
# 26                                     HR DATA ANALYST
# 27   CAMPUS SECURITY & ADMIN SUPPORT EXECUTIVE (DAT...
# 28                  RDA/Metrology and Big Data Manager
# 29   Transport Analyst - Science Industry ($3.5K to...
# ..                                                 ...
# 298        Product Engineer (Healthcare) (KXR/RSE/VL3)
# 299  EXECUTIVE ENGINEER (Digitalisation and IOT sys...
# 300       SEO/SEM (Search Engine Marketing Specialist)
# 301            Supplier Quality Engineer (KDM/SCM/WC3)
# 302  System Engineer (Autonomous Vehicle) (KXR/RSE/SY)
# 303             Troubleshooting Engineer (KDM/ILS/KW1)
# 304           EXECUTIVE ENGINEER (Information Systems)
# 305                           Optical Systems Engineer
# 306                                   Systems Engineer
# 307             Troubleshooting Engineer (KDM/ILS/KW1)
# 308  System Engineer (Autonomous Vehicle) (KXR/RSE/SY)
# 309  Robotics Engineer  (Shared Services) (KXR/STAI...
# 310             STC Senior Engineer - Photolithography
# 311        Product Engineer (Healthcare) (KXR/RSE/VL3)
# 312  Order & Inventory Management Executive (KIS/AS...
# 313                      Senior Manager (CBG/SGBC/LWL)
# 314    APD Singapore Equipment Development Sr Engineer
# 315  Assistant Principal Engineer/ Senior Engineer ...
# 316  Assistant/ Principal Engineer (Electronics/Ele...
# 317                  System Engineer (AME/EDC/PMC/JC1)
# 318                                          Innovator
# 319  Consultant/Senior Consultant, Instructional De...
# 320            Supplier Quality Engineer (KDM/SCM/WC3)
# 321                         SQL DATABASE ADMINISTRATOR
# 322                           BUSINESS PROCESS ANALYST
# 323                           MSB - Equipment Engineer
# 324                    NVE SSD Senior/Product Engineer
# 325                                 Research Executive
# 326                                    Project Manager
# 327                                 Product Specialist
#
#                                                Company  \
# 0    Micron Semiconductor Asia Date Posted: 28-Jan-...
# 1    Micron Semiconductor Asia Date Posted: 15-Jan-...
# 2    Micron Semiconductor Asia Date Posted: 26-Dec-...
# 3    Optimum Solutions (S) Pte Ltd Date Posted: 5-J...
# 4                DBS Bank Ltd Date Posted: 12-Dec-2017
# 5                DBS Bank Ltd Date Posted: 14-Jan-2018
# 6    The Search Executives Pte Ltd (EA Licence No: ...
# 7    The Search Executives Pte Ltd (EA Licence No: ...
# 8    The Search Executives Pte Ltd (EA Licence No: ...
# 9    MavenTree Technology Pte Ltd Date Posted: 20-J...
# 10        Aryan Search Pte Ltd Date Posted: 9-Jan-2018
# 11   ServLink Technology Resources Pte Ltd Date Pos...
# 12   Singapore Technologies Kinetics Ltd Date Poste...
# 13   Singapore Technologies Kinetics Ltd Date Poste...
# 14   Singapore Technologies Kinetics Ltd Date Poste...
# 15   Adecco Personnel Pte Ltd Date Posted: 27-Jan-2018
# 16   Illumina Singapore Pte Ltd Date Posted: 12-Jan...
# 17   THATZ International Pte Ltd Date Posted: 19-Ja...
# 18       Aryan Search Pte Ltd Date Posted: 15-Jan-2018
# 3    [<p></p>, <p> <span>Responsibilities<br/>
# <br/...
# 4    [<p><b>Business Function</b></p>, <p></p>, <p>...
# 5    [<p><b>Business Function</b> </p>, <p></p>, <p...
# 6    [<p><span><span><br/>
# Must Have:</span><br/>
# <...
# 7    [<p><span><br/>
# <span>Good To Have:<br/>
# <br/>...
# 8    [<p><span> </span></p>, <p><span>Requirements:...
# 9    [<p><br/></p>, <p><br/></p>, <p _ngcontent-c2=...
# 10   [<p></p>, <p> <span>We are looking for a <stro...
# 11   [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 12   [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 13   [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 14   [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 15   [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 16   [<p><b>Position Summary:</b><br/><br/>This pos...
# 17   [<p><strong><span>Key Area of Responsibilities...
# 18   [<p></p>, <p> <span>We are looking for a <stro...
# 19   [<p><span>You will derive policy insights from...
# 20   [<p><strong>Responsibilities</strong> </p>, <p...
# 21   [<p><strong>Role: Network Data Architect</stro...
# 22   [<p>Req. ID: 84487 </p>, <p><strong>Responsibi...
# 23   [<p>Req. ID: 103043 </p>, <p><strong>Responsib...
# 24   [<p></p>, <p>Req. ID: 86425 </p>, <p><strong>M...
# 25   [<p><strong></strong></p>, <p>Req. ID: 86425 <...
# 26   [<p></p>, <p>Req. ID: 94577 </p>, <p>Do you be...
# 27   [<p><span>We are looking for suitable candidat...
# 28   [<p></p>, <p>Req. ID: 105627 </p>, <p><strong>...
# 29   [<p><span><strong>Key Job Activities</strong><...
# ..                                                 ...
# 298  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 299  [<p></p>, <p><strong> </strong></p>, <p><span>...
# 300  [<p><strong><span>Job Overview:</span></strong...
# 301  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 302  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 303  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 304  [<p><br/></p>, <p><strong>Requirements<br/>
#  <...
# 305  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 306  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 307  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 308  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 309  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 310  [<p></p>, <p>Req. ID: 95091 </p>, <p><strong>D...
# 311  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 312  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 313  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 314  [<p></p>, <p>Req. ID: 105201 </p>, <p><strong>...
# 315  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 316  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 317  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 318  [<p><strong><span>Job Requirements:</span></st...
# 319  [<p><span></span></p>, <p><span>As a Consultan...
# 320  [<p _ngcontent-c2="">78 Shenton Way, #09-01</p...
# 321  [<p><strong>Job Description:</strong></p>, <p>...
# 322  [<p></p>, <p>Req. ID: 104642 </p>, <p>As a Bus...
# 323  [<p></p>, <p>Req. ID: 104064 </p>, <p>Responsi...
# 324  [<p></p>, <p>Req. ID: 99482 </p>, <p><strong>R...
# 325  [<p><br/></p>, <p></p>, <p><strong>Primary res...
# 326  [<p><strong><span>Job Description</span></stro...
# 327  [<p><br/></p>, <p><strong>Job Description</str...
#
# [328 rows x 3 columns]

# %%
import sys
sys.setrecursionlimit(100000)

# %%
pickle_out = open("jobscent","wb")
pickle.dump(df, pickle_out)
pickle_out.close()
